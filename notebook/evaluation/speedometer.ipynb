# %% [markdown]
# # Setup

# %%
import os
import logging as log

from lisa.utils import setup_logging
setup_logging(level=log.ERROR)

from lisa.trace import Trace
from lisa.wa import WAOutput
from lisa.stats import Stats
from lisa.datautils import series_mean
from pandas import DataFrame
import pandas as pd
import polars as pl
import scipy as sp
import numpy as np
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
import holoviews as hv
from holoviews import opts
from bokeh.themes import built_in_themes
from tabulate import tabulate
from pathlib import Path

from holoviews.operation.datashader import datashade, rasterize
from holoviews.operation import decimate

from wp.notebook import WorkloadNotebookAnalysis, setup_notebook

setup_notebook()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='cd2d0040-2266-4e16-bd95-b256faf11f2e'>
#   <div id="d7421bb9-089b-4a9c-99e2-49a4f582fd9c" data-root-id="cd2d0040-2266-4e16-bd95-b256faf11f2e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7a8f08c5-2a2b-4363-be1e-8cb2d0547414":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"cd2d0040-2266-4e16-bd95-b256faf11f2e"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"c21dbc87-8bf3-47f7-b84e-38d46923dc72","attributes":{"plot_id":"cd2d0040-2266-4e16-bd95-b256faf11f2e","comm_id":"8f2fcb9e3cd548958e31f1a4da39db4b","client_comm_id":"2e76812770a04514b0ff86dac679ee31"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"nam ...
#   var render_items = [{"docid":"7a8f08c5-2a2b-4363-be1e-8cb2d0547414","roots":{"cd2d0040-2266-4e16-bd95-b256faf11f2e":"d7421bb9-089b-4a9c-99e2-49a4f582fd9c"},"root_ids":["cd2d0040-2266-4e16-bd95-b256faf11f2e"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Plotly'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# ## Runs

# %%
sp = WorkloadNotebookAnalysis('/home/kajetan/uofg/ml-idle/workloads', [
    'speedometer_menu_idle_10_1412',
    'speedometer_teo_deltatrace_10_1703',
    'speedometer_mlidle_7f_8d_10_2003',
    'speedometer_mlidle_7f_10_2003',
])

sp.show()
# Out:
#                metric  value             unit  iteration     workload   id  \
# 0   Speedometer Score  78.34  Runs per minute          1  speedometer  wk1
# 1   Speedometer Score  73.47  Runs per minute          2  speedometer  wk1
# 2   Speedometer Score  71.76  Runs per minute          3  speedometer  wk1
# 3   Speedometer Score  69.19  Runs per minute          4  speedometer  wk1
# 4   Speedometer Score  67.09  Runs per minute          5  speedometer  wk1
# 5   Speedometer Score  66.42  Runs per minute          6  speedometer  wk1
# 6   Speedometer Score  65.70  Runs per minute          7  speedometer  wk1
# 7   Speedometer Score  63.56  Runs per minute          8  speedometer  wk1
# 8   Speedometer Score  63.35  Runs per minute          9  speedometer  wk1
# 9   Speedometer Score  63.07  Runs per minute         10  speedometer  wk1
# 10  Speedometer Score  82.58  Runs per minute          1  speedometer  wk1
# 11  Speedometer Score  77.91  Runs per minute          2  speedometer  wk1
# 12  Speedometer Score  74.57  Runs per minute          3  speedometer  wk1
# 13  Speedometer Score  70.45  Runs per minute          4  speedometer  wk1
# 14  Speedometer Score  69.00  Runs per minute          5  speedometer  wk1
# 15  Speedometer Score  67.54  Runs per minute          6  speedometer  wk1
# 16  Speedometer Score  65.64  Runs per minute          7  speedometer  wk1
# 17  Speedometer Score  64.62  Runs per minute          8  speedometer  wk1
# 18  Speedometer Score  63.57  Runs per minute          9  speedometer  wk1
# 19  Speedometer Score  61.67  Runs per minute         10  speedometer  wk1
# 20  Speedometer Score  79.07  Runs per minute          1  speedometer  wk1
# 21  Speedometer Score  72.85  Runs per minute          2  speedometer  wk1
# 22  Speedometer Score  68.56  Runs per minute          3  speedometer  wk1
# 23  Speedometer Score  65.67  Runs per minute          4  speedometer  wk1
# 24  Speedometer Score  65.24  Runs per minute          5  speedometer  wk1
# 25  Speedometer Score  62.40  Runs per minute          6  speedometer  wk1
# 26  Speedometer Score  62.05  Runs per minute          7  speedometer  wk1
# 27  Speedometer Score  59.88  Runs per minute          8  speedometer  wk1
# 28  Speedometer Score  59.63  Runs per minute          9  speedometer  wk1
# 29  Speedometer Score  59.14  Runs per minute         10  speedometer  wk1
# 30  Speedometer Score  84.43  Runs per minute          1  speedometer  wk1
# 31  Speedometer Score  77.80  Runs per minute          2  speedometer  wk1
# 32  Speedometer Score  75.47  Runs per minute          3  speedometer  wk1
# 33  Speedometer Score  72.30  Runs per minute          4  speedometer  wk1
# 34  Speedometer Score  69.35  Runs per minute          5  speedometer  wk1
# 35  Speedometer Score  67.74  Runs per minute          6  speedometer  wk1
# 36  Speedometer Score  67.37  Runs per minute          7  speedometer  wk1
# 37  Speedometer Score  65.55  Runs per minute          8  speedometer  wk1
# 38  Speedometer Score  64.97  Runs per minute          9  speedometer  wk1
# 39  Speedometer Score  63.85  Runs per minute         10  speedometer  wk1
#
#                                wa_path                              kernel  \
# 0        speedometer_menu_idle_10_1412  6.3.0-mainline-g7c68bfdc80c5-dirty
# 1        speedometer_menu_idle_10_1412  6.3.0-mainline-g7c68bfdc80c5-dirty
# 2        speedometer_menu_idle_10_1412  6.3.0-mainline-g7c68bfdc80c5-dirty
# 3        speedometer_menu_idle_10_1412  6.3.0-mainline-g7c68bfdc80c5-dirty
# 4        speedometer_menu_idle_10_1412  6.3.0-mainline-g7c68bfdc80c5-dirty
# 5        speedometer_menu_idle_10_1412  6.3.0-mainline-g7c68bfdc80c5-dirty
# 6        speedometer_menu_idle_10_1412  6.3.0-mainline-g7c68bfdc80c5-dirty
# 7        speedometer_menu_idle_10_1412  6.3.0-mainline-g7c68bfdc80c5-dirty
# 8        speedometer_menu_idle_10_1412  6.3.0-mainline-g7c68bfdc80c5-dirty
# 9        speedometer_menu_idle_10_1412  6.3.0-mainline-g7c68bfdc80c5-dirty
# 10  speedometer_teo_deltatrace_10_1703  6.3.0-mainline-g664fb1e13797-dirty
# 11  speedometer_teo_deltatrace_10_1703  6.3.0-mainline-g664fb1e13797-dirty
# 12  speedometer_teo_deltatrace_10_1703  6.3.0-mainline-g664fb1e13797-dirty
# 13  speedometer_teo_deltatrace_10_1703  6.3.0-mainline-g664fb1e13797-dirty
# 14  speedometer_teo_deltatrace_10_1703  6.3.0-mainline-g664fb1e13797-dirty
# 15  speedometer_teo_deltatrace_10_1703  6.3.0-mainline-g664fb1e13797-dirty
# 16  speedometer_teo_deltatrace_10_1703  6.3.0-mainline-g664fb1e13797-dirty
# 17  speedometer_teo_deltatrace_10_1703  6.3.0-mainline-g664fb1e13797-dirty
# 18  speedometer_teo_deltatrace_10_1703  6.3.0-mainline-g664fb1e13797-dirty
# 19  speedometer_teo_deltatrace_10_1703  6.3.0-mainline-g664fb1e13797-dirty
# 20    speedometer_mlidle_7f_8d_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 21    speedometer_mlidle_7f_8d_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 22    speedometer_mlidle_7f_8d_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 23    speedometer_mlidle_7f_8d_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 24    speedometer_mlidle_7f_8d_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 25    speedometer_mlidle_7f_8d_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 26    speedometer_mlidle_7f_8d_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 27    speedometer_mlidle_7f_8d_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 28    speedometer_mlidle_7f_8d_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 29    speedometer_mlidle_7f_8d_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 30       speedometer_mlidle_7f_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 31       speedometer_mlidle_7f_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 32       speedometer_mlidle_7f_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 33       speedometer_mlidle_7f_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 34       speedometer_mlidle_7f_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 35       speedometer_mlidle_7f_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 36       speedometer_mlidle_7f_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 37       speedometer_mlidle_7f_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 38       speedometer_mlidle_7f_10_2003  6.3.0-mainline-g664fb1e13797-dirty
# 39       speedometer_mlidle_7f_10_2003  6.3.0-mainline-g664fb1e13797-dirty
#
#                tag
# 0        menu_idle
# 1        menu_idle
# 2        menu_idle
# 3        menu_idle
# 4        menu_idle
# 5        menu_idle
# 6        menu_idle
# 7        menu_idle
# 8        menu_idle
# 9        menu_idle
# 10  teo_deltatrace
# 11  teo_deltatrace
# 12  teo_deltatrace
# 13  teo_deltatrace
# 14  teo_deltatrace
# 15  teo_deltatrace
# 16  teo_deltatrace
# 17  teo_deltatrace
# 18  teo_deltatrace
# 19  teo_deltatrace
# 20    mlidle_7f_8d
# 21    mlidle_7f_8d
# 22    mlidle_7f_8d
# 23    mlidle_7f_8d
# 24    mlidle_7f_8d
# 25    mlidle_7f_8d
# 26    mlidle_7f_8d
# 27    mlidle_7f_8d
# 28    mlidle_7f_8d
# 29    mlidle_7f_8d
# 30       mlidle_7f
# 31       mlidle_7f
# 32       mlidle_7f
# 33       mlidle_7f
# 34       mlidle_7f
# 35       mlidle_7f
# 36       mlidle_7f
# 37       mlidle_7f
# 38       mlidle_7f
# 39       mlidle_7f
# benchmark_dirs: ['speedometer_menu_idle_10_1412', 'speedometer_teo_deltatrace_10_1703', 'speedometer_mlidle_7f_8d_10_2003', 'speedometer_mlidle_7f_10_2003']
# tags: ['menu_idle', 'teo_deltatrace', 'mlidle_7f_8d', 'mlidle_7f']
# kernels: ['6.3.0-mainline-g7c68bfdc80c5-dirty', '6.3.0-mainline-g664fb1e13797-dirty', '6.3.0-mainline-g664fb1e13797-dirty', '6.3.0-mainline-g664fb1e13797-dirty']

# %% [markdown]
# # Benchmark scores

# %% [markdown]
# ## Line plot

# %%
sp.plot.results_line(['Speedometer Score'])
# Out:
# :NdLayout   [metric]
#    :NdOverlay   [tag]
#       :Curve   [iteration]   (value)

# %% [markdown]
# ## Bar plot

# %%
sp.plot.results_bar(['Speedometer Score'], width=1000)
# Out:
# +-------------------+----------------+-------+-----------+
# |      metric       |      tag       | value | perc_diff |
# +-------------------+----------------+-------+-----------+
# | Speedometer Score |   menu_idle    | 68.0  |   0.0%    |
# | Speedometer Score | teo_deltatrace | 69.5  |   2.11%   |
# | Speedometer Score |  mlidle_7f_8d  | 65.2  |   -4.2%   |
# | Speedometer Score |   mlidle_7f    | 70.6  |   3.8%    |
# +-------------------+----------------+-------+-----------+
# <iframe
#     scrolling="no"
#     width="1020px"
#     height="620"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Overutilized

# %% [markdown]
# ## Line plot

# %%
sp.plot.overutilized_line()

# %% [markdown]
# # Perf

# %% [markdown]
# ## Line plot

# %%
sp.plot.perf_line()

# %% [markdown]
# ## Bar plot

# %%
sp.plot.perf_bar()

# %% [markdown]
# # Idle residency

# %% [markdown]
# ## Bar plot

# %%
sp.plot.idle_residency_bar()

# %% [markdown]
# # Idle misses

# %%
def workload_idle_baseline_accuracy(path):
    print('Baseline for', path)
    cpu_idle = pl.read_parquet(path / 'analysis' / 'cpu_idle.pqt')
    wakeups = cpu_idle.filter(pl.col('state') == -1)
    cpu_idle_miss = pl.read_parquet(path / 'analysis' / 'cpu_idle_miss.pqt')
    
    print('accuracy', 1 - cpu_idle_miss.height / wakeups.height)
    print('misses', cpu_idle_miss.height / wakeups.height)
    print('too deep', cpu_idle_miss.filter(pl.col('state') == 1).height / wakeups.height, 'too shallow', cpu_idle_miss.filter(pl.col('state') == 0).height / wakeups.height)
    print()

    return (wakeups.height, cpu_idle_miss.height)

for out in sp.wa_outputs:
    path = Path(out.path)
    workload_idle_baseline_accuracy(path)
# Out:
# Baseline for /home/kajetan/uofg/ml-idle/workloads/speedometer_menu_idle_10_1412
# accuracy 0.7800750738896148
# misses 0.21992492611038514
# too deep 0.18292211339068337 too shallow 0.037002812719701766
#
# Baseline for /home/kajetan/uofg/ml-idle/workloads/speedometer_teo_deltatrace_10_1703
# accuracy 0.8340002848091004
# misses 0.16599971519089965
# too deep 0.008457420334523798 too shallow 0.15754229485637586
#
# Baseline for /home/kajetan/uofg/ml-idle/workloads/speedometer_mlidle_7f_8d_10_2003
# accuracy 0.9246522744372973
# misses 0.07534772556270275
# too deep 0.004395425853115044 too shallow 0.0709522997095877
#
# Baseline for /home/kajetan/uofg/ml-idle/workloads/speedometer_mlidle_7f_10_2003
# accuracy 0.837907295594932
# misses 0.16209270440506798
# too deep 0.01786955526118224 too shallow 0.14422314914388576

# %% [markdown]
# ## Bar plot

# %%
sp.plot.idle_miss_bar()

# %% [markdown]
# # Power usage

# %% [markdown]
# ## Line plot

# %%
sp.plot.power_meter_line()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="1020"
#     src="iframe_figures/figure_7.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Bar plot

# %%
sp.plot.power_meter_bar()
# Out:
# +------------+--------+----------------+--------+-----------+
# |  channel   | metric |      tag       | value  | perc_diff |
# +------------+--------+----------------+--------+-----------+
# |    CPU     | gmean  |   menu_idle    | 1652.3 |   0.0%    |
# |  CPU-Big   | gmean  |   menu_idle    | 1211.2 |   0.0%    |
# | CPU-Little | gmean  |   menu_idle    | 362.8  |   0.0%    |
# |  CPU-Mid   | gmean  |   menu_idle    |  77.0  |   0.0%    |
# |    GPU     | gmean  |   menu_idle    |  15.0  |   0.0%    |
# |   Total    | gmean  |   menu_idle    | 1667.3 |   0.0%    |
# |    CPU     | gmean  | teo_deltatrace | 1705.1 |   3.2%    |
# |  CPU-Big   | gmean  | teo_deltatrace | 1255.8 |   3.68%   |
# | CPU-Little | gmean  | teo_deltatrace | 366.9  |   1.13%   |
# |  CPU-Mid   | gmean  | teo_deltatrace |  81.3  |   5.57%   |
# |    GPU     | gmean  | teo_deltatrace |  15.1  |   0.35%   |
# |   Total    | gmean  | teo_deltatrace | 1720.2 |   3.17%   |
# |    CPU     | gmean  |  mlidle_7f_8d  | 1719.6 |   4.07%   |
# |  CPU-Big   | gmean  |  mlidle_7f_8d  | 1221.6 |   0.86%   |
# | CPU-Little | gmean  |  mlidle_7f_8d  | 408.0  |  12.47%   |
# |  CPU-Mid   | gmean  |  mlidle_7f_8d  |  88.4  |  14.78%   |
# |    GPU     | gmean  |  mlidle_7f_8d  |  15.1  |   0.29%   |
# |   Total    | gmean  |  mlidle_7f_8d  | 1734.7 |   4.04%   |
# |    CPU     | gmean  |   mlidle_7f    | 1726.0 |   4.46%   |
# |  CPU-Big   | gmean  |   mlidle_7f    | 1276.7 |   5.41%   |
# | CPU-Little | gmean  |   mlidle_7f    | 366.1  |   0.9%    |
# |  CPU-Mid   | gmean  |   mlidle_7f    |  82.1  |   6.65%   |
# |    GPU     | gmean  |   mlidle_7f    |  15.3  |   1.88%   |
# |   Total    | gmean  |   mlidle_7f    | 1741.4 |   4.44%   |
# +------------+--------+----------------+--------+-----------+
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_13.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Energy estimate

# %% [markdown]
# ## Line plot

# %%
sp.plot.energy_estimate_line()

# %% [markdown]
# ## Bar plot

# %%
sp.plot.energy_estimate_bar()

# %% [markdown]
# # Thermal

# %% [markdown]
# ## Line plot

# %%
sp.plot.thermal_line()

# %% [markdown]
# ## Bar plot

# %%
sp.plot.thermal_bar()

# %% [markdown]
# # Frequency

# %% [markdown]
# ## Line plot

# %%
sp.plot.frequency_line()

# %% [markdown]
# ## Bar plot

# %%
sp.plot.frequency_bar()

# %% [markdown]
# # CFS signals

# %% [markdown]
# ## Line plot

# %%
sp.plot.sched_pelt_cfs_line()

# %% [markdown]
# ## Bar plot

# %%
sp.plot.sched_pelt_cfs_bar()

# %% [markdown]
# # Wakeup latency - tasks

# %% [markdown]
# ## Line plot

# %%
sp.plot.wakeup_latency_line(height=1100, columns=4)

# %% [markdown]
# ## Bar plot

# %%
sp.plot.wakeup_latency_bar(height=1000, columns=4)

# %% [markdown]
# ## Quantiles

# %%
sp.plot.wakeup_latency_quantiles_bar(height=2000, columns=2)

# %% [markdown]
# # Wakeup latency - cgroups

# %% [markdown]
# ## Line plot

# %%
sp.plot.wakeup_latency_cgroup_line()

# %% [markdown]
# ## Bar plot

# %%
sp.plot.wakeup_latency_cgroup_bar()

# %% [markdown]
# ## Quantiles

# %%
sp.plot.wakeup_latency_cgroup_quantiles_bar()

# %% [markdown]
# # CPU residency - tasks

# %% [markdown]
# ## Clusters - Line plot

# %%
sp.plot.tasks_cpu_residency_cluster_line()

# %% [markdown]
# ## Clusters - Bar plot

# %%
sp.plot.tasks_cpu_residency_cluster_bar()

# %% [markdown]
# ## Clusters - Per-task bar plot

# %%
sp.plot.tasks_cpu_residency_per_task_bar()

# %% [markdown]
# ## CPUs - Bar plot

# %%
sp.plot.tasks_cpu_residency_cpu_bar()

# %% [markdown]
# # CPU residency - cgroups

# %% [markdown]
# ## Clusters - Bar plot

# %%
sp.plot.cgroup_cpu_residency_cluster_bar()

# %% [markdown]
# ## CPUs - Bar plot

# %%
sp.plot.cgroup_cpu_residency_cpu()

# %% [markdown]
# # Summary - TLDR

# %%
sp.plot.summary()
# Out:
# Speedometer
# +-------------------+---------------+----------------+----------------+
# |      metric       |   menu_idle   | teo_deltatrace |   mlidle_7f    |
# +-------------------+---------------+----------------+----------------+
# | Speedometer Score |  68.0 (0.0%)  |  69.5 (2.11%)  |  70.6 (3.8%)   |
# |  CPU_total_power  | 1652.3 (0.0%) | 1705.1 (3.2%)  | 1726.0 (4.46%) |
# +-------------------+---------------+----------------+----------------+
# tag             metric      menu_idle teo_deltatrace       mlidle_7f
# 0    Speedometer Score    68.0 (0.0%)   69.5 (2.11%)     70.6 (3.8%)
# 1      CPU_total_power  1652.3 (0.0%)  1705.1 (3.2%)  1726.0 (4.46%)

# %% [markdown]
# ## Save image plots

# %%
sp.save_image_plots('/home/kajpuc01/temp/sp_vh_impact')
